# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('data/data.csv')

# %%
data.shape
# Out:
# (700000, 26)

# %%
data.sample(5)
# Out:
#             id  age  alcohol_consumption_per_week  \
# 478332  478332   40                             2
# 660584  660584   60                             1
# 121551  121551   53                             4
# 22082    22082   51                             1
# 105771  105771   40                             1
#
#         physical_activity_minutes_per_week  diet_score  sleep_hours_per_day  \
# 478332                                  71         4.9                  6.0
# 660584                                  57         5.1                  6.2
# 121551                                  54         8.2                  8.2
# 22082                                   89         5.4                  9.1
# 105771                                  37         5.4                  6.3
#
#         screen_time_hours_per_day   bmi  waist_to_hip_ratio  systolic_bp  ...  \
# 478332                        5.1  27.1                0.89          133  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700000 entries, 0 to 699999
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   id                                  700000 non-null  int64
#  1   age                                 700000 non-null  int64
#  2   alcohol_consumption_per_week        700000 non-null  int64
#  3   physical_activity_minutes_per_week  700000 non-null  int64
#  4   diet_score                          700000 non-null  float64
#  5   sleep_hours_per_day                 700000 non-null  float64
#  6   screen_time_hours_per_day           700000 non-null  float64
#  7   bmi                                 700000 non-null  float64
#  8   waist_to_hip_ratio                  700000 non-null  float64
#  9   systolic_bp                         700000 non-null  int64
#  10  diastolic_bp                        700000 non-null  int64
# ...

# %%
data.describe().T
# Out:
#                                        count           mean            std  \
# id                                  700000.0  349999.500000  202072.738554
# age                                 700000.0      50.359734      11.655520
# alcohol_consumption_per_week        700000.0       2.072411       1.048189
# physical_activity_minutes_per_week  700000.0      80.230803      51.195071
# diet_score                          700000.0       5.963695       1.463336
# sleep_hours_per_day                 700000.0       7.002200       0.901907
# screen_time_hours_per_day           700000.0       6.012733       2.022707
# bmi                                 700000.0      25.874684       2.860705
# waist_to_hip_ratio                  700000.0       0.858766       0.037980
# systolic_bp                         700000.0     116.294193      11.010390
# diastolic_bp                        700000.0      75.440924       6.825775
# ...

# %%
data.describe(include='object')
# Out:
#         gender ethnicity education_level income_level smoking_status  \
# count   700000    700000          700000       700000         700000
# unique       3         5               4            5              3
# top     Female     White      Highschool       Middle          Never
# freq    363237    386153          344145       290557         494448
#
#        employment_status
# count             700000
# unique                 4
# top             Employed
# freq              516170

# %%
data.isna().sum()
# Out:
# id                                    0
# age                                   0
# alcohol_consumption_per_week          0
# physical_activity_minutes_per_week    0
# diet_score                            0
# sleep_hours_per_day                   0
# screen_time_hours_per_day             0
# bmi                                   0
# waist_to_hip_ratio                    0
# systolic_bp                           0
# diastolic_bp                          0
# heart_rate                            0
# cholesterol_total                     0
# hdl_cholesterol                       0
# ldl_cholesterol                       0
# triglycerides                         0
# gender                                0
# ethnicity                             0
# education_level                       0
# income_level                          0
# smoking_status                        0
# employment_status                     0
# family_history_diabetes               0
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
for i in ['age', 'alcohol_consumption_per_week',
       'physical_activity_minutes_per_week', 'diet_score',
       'sleep_hours_per_day', 'screen_time_hours_per_day', 'bmi',
       'waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp', 'heart_rate',
       'cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol',
       'triglycerides']:
    sns.histplot(data=data,x=i,kde=True)
    plt.show()

# %%
for i in data.select_dtypes(include='object').columns:
    sns.countplot(data=data,x=i,hue='diagnosed_diabetes')
    plt.show()

# %%
for i in  ['family_history_diabetes', 'hypertension_history','cardiovascular_history', 'diagnosed_diabetes']:
    sns.countplot(data=data,x=i)
    plt.show()

# %%
for i in data.select_dtypes(include='object').columns:
    print(data[[i,'diagnosed_diabetes']].groupby([i]).mean())
    print('--'*20)
# Out:
#         diagnosed_diabetes
# gender
# Female            0.622205
# Male              0.624294
# Other             0.640566
# ----------------------------------------
#            diagnosed_diabetes
# ethnicity
# Asian                0.628493
# Black                0.623879
# Hispanic             0.616314
# Other                0.635936
# White                0.624105
# ----------------------------------------
#                  diagnosed_diabetes
# education_level
# Graduate                   0.627008
# Highschool                 0.621462
# No formal                  0.636066
# Postgraduate               0.616647
# ----------------------------------------
#               diagnosed_diabetes
# income_level
# High                    0.623593
# Low                     0.630328
# Lower-Middle            0.626835
# Middle                  0.620291
# Upper-Middle            0.620420
# ----------------------------------------
#                 diagnosed_diabetes
# smoking_status
# ...

# %%
for i in ['age', 'alcohol_consumption_per_week','physical_activity_minutes_per_week', 'diet_score','sleep_hours_per_day', 'screen_time_hours_per_day', 'bmi','waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp', 'heart_rate','cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol','triglycerides']:
    sns.boxplot(data=data,x=i)
    plt.show()

# %%
for i in ['age', 'alcohol_consumption_per_week','physical_activity_minutes_per_week', 'diet_score','sleep_hours_per_day', 'screen_time_hours_per_day', 'bmi','waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp', 'heart_rate','cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol','triglycerides']:
    Q1 = data[i].quantile(0.25)
    Q3 = data[i].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - IQR
    upper_limit = Q3 + IQR
    outlier = data[(data[i]<lower_limit) | (data[i]>upper_limit)]
    percent_outlier = (len(outlier)/len(data[i]))*100
    print(i,lower_limit,upper_limit)
    print(i,percent_outlier)
    print('--'*10)
# Out:
# age 26.0 74.0
# age 2.7641428571428572
# --------------------
# alcohol_consumption_per_week -1.0 5.0
# alcohol_consumption_per_week 0.46242857142857147
# --------------------
# physical_activity_minutes_per_week 2.0 143.0
# physical_activity_minutes_per_week 7.579142857142856
# --------------------
# diet_score 3.0 9.0
# diet_score 3.672857142857143
# --------------------
# sleep_hours_per_day 5.200000000000001 8.799999999999999
# sleep_hours_per_day 5.319714285714286
# --------------------
# screen_time_hours_per_day 1.799999999999999 10.200000000000001
# screen_time_hours_per_day 3.4575714285714287
# --------------------
# bmi 19.999999999999996 31.700000000000003
# bmi 3.9302857142857146
# --------------------
# waist_to_hip_ratio 0.7799999999999999 0.93
# waist_to_hip_ratio 3.676
# --------------------
# systolic_bp 92.0 140.0
# systolic_bp 1.5141428571428572
# --------------------
# diastolic_bp 62.0 89.0
# diastolic_bp 4.022571428571429
# --------------------
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression

# %%
num_col = ['age', 'alcohol_consumption_per_week','physical_activity_minutes_per_week', 'diet_score','sleep_hours_per_day', 'screen_time_hours_per_day', 'bmi','waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp', 'heart_rate','cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol','triglycerides']
ord_col = ['education_level','income_level']
ord_categories = [['No formal','Highschool','Graduate','Postgraduate'],['Low','Lower-Middle','Middle','Upper-Middle','High']]
ohe_col = ['gender', 'ethnicity', 'smoking_status', 'employment_status']

# %%
numeric_transformer = Pipeline(
    steps=[
        ('impute',SimpleImputer(strategy='median')),
        ('scaling',StandardScaler())
    ]
)

# %%
ordinal_transformer = Pipeline(
    steps=[
        ('impute',SimpleImputer(strategy='most_frequent')),
        ('encoding',OrdinalEncoder(categories=ord_categories))
    ]
)

# %%
ohe_transformer = Pipeline(
    steps=[
        ('impute',SimpleImputer(strategy='most_frequent')),
        ('encoding',OneHotEncoder())
    ]
)

# %%
Preprocessor = ColumnTransformer(
    transformers=[
        ('numeric',numeric_transformer,num_col),
        ('ordinal',ordinal_transformer,ord_col),
        ('onehotencoding',ohe_transformer,ohe_col)
    ],remainder='passthrough'
)

# %%
model = Pipeline(
    steps=[
        ('preprocess',Preprocessor),
        ('model',LogisticRegression(max_iter=1000))
    ]
)

# %%
x = data.drop(['diagnosed_diabetes'],axis=1)
y = data['diagnosed_diabetes']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numeric',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaling',
#                                                                    StandardScaler())]),
#                                                   ['age',
#                                                    'alcohol_consumption_per_week',
#                                                    'physical_activity_minutes_per_week',
#                                                    'diet_score',
#                                                    'sleep_hours_per_day',
#                                                    'screen_time_hours_per_day',
# ...

# %%
y_pred = model.predict(x_test)

# %%
print(model.score(x_train,y_train))
# Out:
# 0.6630767857142857

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,roc_auc_score,f1_score
print('acc',accuracy_score(y_test,y_pred))
print('precision',precision_score(y_test,y_pred))
print('recall',recall_score(y_test,y_pred))
print('f1',f1_score(y_test,y_pred))
print('roc_auc_score',roc_auc_score(y_test,y_pred))
# Out:
# acc 0.6639285714285714
# precision 0.6813413787194127
# recall 0.8656902854654428
# f1 0.7625320493408435
# roc_auc_score 0.5978937784671874
